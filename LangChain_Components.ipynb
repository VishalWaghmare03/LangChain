# %% [markdown]
# # LANGCHAIN COMPONENT

# %%
from IPython.display import Image
Image(filename='/home/vishal/Pictures/Screenshots/Screenshot from 2025-02-17 21-28-41.png')

# %% [markdown]
# ## 1.Models
#
# In LangChain "Models" are the core interfaces through which you interact with AI model.

# %%
Image(filename='/home/vishal/Pictures/Screenshots/Screenshot from 2025-02-17 21-26-14.png')

# %% [markdown]
# Different API provided written their code in different way. Which means in my application i want to use two different APIs then i need to write two different code.
# Langchain understand this promblem and create a interface. by using it we can make call with any company API in standard fashion or by doing litle change in the code.
#
# ** Can make call with Language Model and Embedding Model **

# %%
Image(filename='/home/vishal/Pictures/Screenshots/Screenshot from 2025-02-17 21-36-23.png')

# %% [markdown]
# ## 2.Prompts
# --> Input provided to LLM

# %%
Image(filename='/home/vishal/Pictures/Screenshots/Screenshot from 2025-02-17 22-43-09.png')

# %%
Image(filename='/home/vishal/Pictures/Screenshots/Screenshot from 2025-02-17 22-48-31.png')

# %% [markdown]
# Few Short Prompting give the examples in the prompt to better understand LLM and it's work like below.

# %%
Image(filename='/home/vishal/Pictures/Screenshots/Screenshot from 2025-02-17 22-52-17.png')

# %% [markdown]
# ## 3.Chains

# %% [markdown]
# Chains is a concept use to create pipelines. Here Previous Stage output automatically go to input for next stage.
# and best thinks is to we don't have to write manual code.

# %% [markdown]
# ## 4.Indexes
# Indexes connect your application to external knowledge-- such as PDFs, websites or databases.

# %% [markdown]
# #### Components
# * Doc Loader
# * Text Splitter
# * Vector Store
# * Retriever
#
# Indexes is the way using which we can build LLM applications which has access to external knowledge source.

# %% [markdown]
# ## 5.Memory

# %%
Image(filename='/home/vishal/Pictures/Screenshots/Screenshot from 2025-02-18 08-15-12.png')

# %%
Image(filename='/home/vishal/Pictures/Screenshots/Screenshot from 2025-02-18 08-23-18.png')

# %% [markdown]
# ## 6.Agents
# -> use create Agents
#
# AI Agents is just evolved form of chatbot where you can perform some actions with help AI agent because it has got reasoning cababilitites and access to Tools.

# %%
#Shine@Hunter$3999
